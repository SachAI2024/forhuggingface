# %% [markdown]
# <a href="https://colab.research.google.com/github/SachAI2024/forhuggingface/blob/main/sailesh_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets huggingface_hub

# %%
from datasets import load_dataset
from huggingface_hub import login
dataset = load_dataset('json',data_files='vader.json')
print(dataset['train'][1])
# Out:
# {'Q': 'Did you walk the dog?', 'A': '[kkshhhh] I let the dog walk itself [hhhkkshh]. It must learn independence [ppffffhhh].'}

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# ...
# Token has not been saved to git credential helper.
# WARNING:huggingface_hub._login:Token has not been saved to git credential helper.

# %%
dataset.push_to_hub('sachAI2024/vader-speak')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/sachAI2024/vader-speak/commit/546c01ddb42c7a43f8a152751e73ee8bb8899201', commit_message='Upload dataset', commit_description='', oid='546c01ddb42c7a43f8a152751e73ee8bb8899201', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/sachAI2024/vader-speak', endpoint='https://huggingface.co', repo_type='dataset', repo_id='sachAI2024/vader-speak'), pr_revision=None, pr_num=None)
